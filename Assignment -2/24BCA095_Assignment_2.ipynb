# %% [markdown]
# # CAUE302: Python Programming — Assignment 2
# ### Sequence Types, Dictionaries, Sets and Functions
#
# **Roll No:** 24BCA095
# **Program:** BCA Semester-III
# **Institute:** Smt. Chandaben Mohanbhai Patel Institute of Computer Applications, CHARUSAT
#
# ---
#
# > Each question below is followed by its solution. Cells that read input with `input()` will prompt when run.

# %% [markdown]
# ## Question 1
#
# Accept a string from the user and convert it into **Uppercase**, **Lowercase**, and **Title Case**.
#
# **Sample Input**
# ```
# Enter string: python programming
# ```
#
# **Expected Output**
# ```
# Uppercase: PYTHON PROGRAMMING
# Lowercase: python programming
# Title Case: Python Programming
# ```

# %%
n = input("Enter String : ")
n = n.upper()
print("Uppercase: "+n)
n = n.lower()
print("Lowercase: "+n)
# Out:
# Enter String : python programming
# Uppercase: PYTHON PROGRAMMING
# Lowercase: python programming

# %% [markdown]
# ## Question 2
#
# Accept a string from the user and display its **First character**, **Last character**, and **Total length** using `len()`.
#
# **Sample Input**
# ```
# Enter string: CHARUSAT
# ```
#
# **Expected Output**
# ```
# First Character: C
# Last Character: T
# Length: 8
# ```

# %%
n = input("Enter String : ")
print(n[0] + "\n" + n[-1] + "\n" + str(len(n)))
# Out:
# Enter String : CHARUSAT
# C
# T
# 8

# %% [markdown]
# ## Question 3
#
# Create a list of 4 fruit names. Append a new fruit to the end using `append()` and print the updated list.
#
# **Sample Input**
# ```
# Initial List: ['apple', 'banana', 'mango']
# Input fruit: cherry
# ```
#
# **Expected Output**
# ```
# Updated List: ['apple', 'banana', 'mango', 'cherry']
# ```

# %%
l = ["Apple", "Banana", "Cherry"]
n = input("Enter Data : ")
l.append(n)
print(l)
# Out:
# Enter Data : cherry
# ['Apple', 'Banana', 'Cherry', 'cherry']

# %% [markdown]
# ## Question 4
#
# Accept 5 numbers from the user into a list. Calculate and print the **Sum** and **Length** of the list.
#
# **Sample Input**
# ```
# Input numbers: 10, 20, 30, 40, 50
# ```
#
# **Expected Output**
# ```
# Total Sum: 150
# Length: 5
# ```

# %%
l = []
sum=0
for i in range(5):
    n = input("Enter Number : ")
    l.append(n)
    sum+= int(n)
print(l)
print("Sum: " + str(sum))
# Out:
# Enter Number : 10
# Enter Number : 20
# Enter Number : 30
# Enter Number : 40
# Enter Number : 50
# ['10', '20', '30', '40', '50']
# Sum: 150

# %% [markdown]
# ## Question 5
#
# Create a tuple containing 4 color names. Display the element at index 2 and print the index of `'blue'` using `index()`.
#
# **Sample Input**
# ```
# Tuple: ('red', 'green', 'blue', 'yellow')
# ```
#
# **Expected Output**
# ```
# Element at Index 2: blue
# Index of 'blue': 2
# ```

# %%
t=("red","green","blue")
n = int(input("Enter Number : "))
print(t[n])
# Out:
# Enter Number : 2
# blue

# %% [markdown]
# ## Question 6
#
# Accept a string from the user and display its **Reverse** using string slicing.
#
# **Sample Input**
# ```
# Enter string: Education
# ```
#
# **Expected Output**
# ```
# Reversed String: noitacudE
# ```

# %%
n=input("Enter String : ")
rn=n[::-1]
print("Reverse String: "+rn)
# Out:
# Enter String : Education
# Reverse String: noitacudE

# %% [markdown]
# ## Question 7
#
# Accept a list of numbers from the user. Display the **Largest** and **Smallest** number using built-in `max()` and `min()` functions.
#
# **Sample Input**
# ```
# Enter numbers: 45, 12, 89, 33, 67
# ```
#
# **Expected Output**
# ```
# Maximum Number: 89
# Minimum Number: 12
# ```

# %%
l=[]
for i in range(5):
    n=int(input("Enter Data : "))
    l.append(n)
print("Maximum : "+str(max(l)))
print("Minimum : "+str(min(l)))
# Out:
# Enter Data : 45
# Enter Data : 12
# Enter Data : 89
# Enter Data : 33
# Enter Data : 67
# Maximum : 89
# Minimum : 12

# %% [markdown]
# ## Question 8
#
# Accept a list of student marks. Sort the list in **Ascending** order using `sort()` and then in **Descending** order using `sort(reverse=True)`.
#
# **Sample Input**
# ```
# Input Marks: [75, 42, 90, 68, 85]
# ```
#
# **Expected Output**
# ```
# Ascending Order: [42, 68, 75, 85, 90]
# Descending Order: [90, 85, 75, 68, 42]
# ```

# %%
l=[]
for i in range(5):
    n=int(input("Enter Data : "))
    l.append(n)
print("Ascending : "+str(sorted(l)))
print("Descending : "+str(sorted(l, reverse=True)))
# Out:
# Enter Data : 75
# Enter Data : 42
# Enter Data : 90
# Enter Data : 68
# Enter Data : 85
# Ascending : [42, 68, 75, 85, 90]
# Descending : [90, 85, 75, 68, 42]

# %% [markdown]
# ## Question 9
#
# Write a Python program to demonstrate **Tuple Unpacking** by storing Roll No, Name, and Course in a tuple and unpacking them into individual variables.
#
# **Sample Input**
# ```
# Tuple: (101, 'Krupa Pathak', 'BCA')
# ```
#
# **Expected Output**
# ```
# Roll No: 101
# Name: Krupa Pathak
# Course: BCA
# ```

# %%
t=("red","green","blue")
roll,name,course = t
print("Roll No : "+str(roll))
print("Name : "+name)
print("Course : "+course)
# Out:
# Roll No : red
# Name : green
# Course : blue

# %% [markdown]
# ## Question 10
#
# Accept a string from the user and count the total number of **Vowels** (a, e, i, o, u) present in it using a loop and count.
#
# **Sample Input**
# ```
# Enter a string: Welcome to CHARUSAT
# ```
#
# **Expected Output**
# ```
# Total Vowels Count = 7
# ```

# %%
n=input("Enter String : ")
count=0
for i in range(len(n)):
    if(n[i] == 'a' or n[i] == 'e' or n[i] == 'i' or n[i] == 'o' or n[i] == 'u'):
        count+=1
print("Number of vowels : "+str(count))
# Out:
# Enter String : Welcome to CHARUSAT
# Number of vowels : 4

# %% [markdown]
# ## Question 11
#
# Accept a string from the user and check whether it is a **Palindrome** (reads the same forward and backward).
#
# **Sample Input**
# ```
# Enter a string: madam
# ```
#
# **Expected Output**
# ```
# madam is a Palindrome string
# ```

# %%
n=input("Enter String : ")
rn = n[::-1]
if(n == rn):
    print("Palindrome")
# Out:
# Enter String : madam
# Palindrome

# %% [markdown]
# ## Question 12
#
# Accept a list of integers from the user and separate them into two new lists: one for **Even** numbers and one for **Odd** numbers.
#
# **Sample Input**
# ```
# Input List: [12, 7, 15, 20, 9, 14]
# ```
#
# **Expected Output**
# ```
# Even Numbers List: [12, 20, 14]
# Odd Numbers List: [7, 15, 9]
# ```

# %%
l=[]
e=[]
o=[]
for i in range(5):
    n=int(input("Enter Data : "))
    l.append(n)
    if(n%2 == 0):
        e.append(n)
    else:
        o.append(n)
print("Even : "+str(e))
print("Odd : "+str(o))
# Out:
# Enter Data : 12
# Enter Data : 7
# Enter Data : 15
# Enter Data : 20
# Enter Data : 9
# Even : [12, 20]
# Odd : [7, 15, 9]

# %% [markdown]
# ## Question 13
#
# Write a Python program to remove all **duplicate elements** from a given list while maintaining the original order.
#
# **Sample Input**
# ```
# Input List: [10, 20, 10, 30, 20, 40]
# ```
#
# **Expected Output**
# ```
# List after removing duplicates: [10, 20, 30, 40]
# ```

# %%
l=[]
for i in range(5):
    n=input("Enter Data : ")
    l.append(n)
nl=list(set(l))
print("Unique List : "+str(nl))
# Out:
# Enter Data : 10
# Enter Data : 20
# Enter Data : 10
# Enter Data : 30
# Enter Data : 20
# Unique List : ['30', '10', '20']

# %% [markdown]
# ## Question 14
#
# Write a Python program to input a password and check whether it meets the following criteria:
#
# - At least 8 characters long
# - Contains at least one digit
# - Contains at least one uppercase letter

# %%
pas = input("Enter password : ")
if(len(pas) < 8):
    print("Password must be at least 8 characters long.")
flag1 = False
flag2 = False
for c in pas:
    if c.isdigit():
        flag1 = True
    if c.isupper():
        flag2 = True

if flag1 != True:
    print("Password must contain at least one digit.")
if flag2 != True:
    print("Password must contain at least one uppercase letter.")
# Out:
# Enter password : pass
# Password must be at least 8 characters long.
# Password must contain at least one digit.
# Password must contain at least one uppercase letter.

# %% [markdown]
# ## Question 15
#
# Write a Python program to find the **average** of all numbers stored in a tuple.

# %%
n = int(input("Enter a number: "))
tup=[]
sum=0
for i in range(n):
    k= int(input("Enter data " + str(i)+ " : "))
    tup.append(k)
tup=tuple(tup)
for j in tup:
    sum+=j    
print(sum)
# Out:
# Enter a number: 5
# Enter data 0 : 10
# Enter data 1 : 20
# Enter data 2 : 30
# Enter data 3 : 40
# Enter data 4 : 50
# 150

# %% [markdown]
# ## Question 16
#
# Write a Python program to find the **second largest** element in a tuple.

# %%
n = int(input("Enter a number: "))
tup=[]
for i in range(n):
    k= int(input("Enter data " + str(i)+ " : "))
    tup.append(k)
tup=tuple(tup)
greatest = 0
great = 0
for i in tup:
    for j in tup:
        if i==j:
            continue
        elif i>j and i>greatest:
            greatest = i
        if greatest>i and  great<i:
            great = i
print(f"{greatest} + {great}")
# Out:
# Enter a number: 5
# Enter data 0 : 45
# Enter data 1 : 12
# Enter data 2 : 89
# Enter data 3 : 33
# Enter data 4 : 67
# 89 + 67

# %% [markdown]
# ## Question 17
#
# Create a dictionary containing five fruits and their prices. Print the complete dictionary.

# %%
dict ={
    "Banana" : 100,
    "Apple" : 200,
    "Mango" : 300,
}
dict1= {}
n = int(input("Enter Size of dict: "))
for i in range(n):
    key = input("Fruit Name : ")
    value = int(input("Price : "))
    dict1[key] = value 
print (dict1)
# Out:
# Enter Size of dict: 5
# Fruit Name : Apple
# Price : 100
# Fruit Name : Banana
# Price : 50
# Fruit Name : Mango
# Price : 120
# Fruit Name : Cherry
# Price : 200
# Fruit Name : Grapes
# Price : 80
# {'Apple': 100, 'Banana': 50, 'Mango': 120, 'Cherry': 200, 'Grapes': 80}

# %% [markdown]
# ## Question 18
#
# Create a dictionary named `subjects` with 5 subject names as keys and marks as values. Print each subject with its marks using a loop.

# %%
dict1= {}
n = int(input("Enter Size of dict: "))
for i in range(n):
    key = input("Fruit Name : ")
    value = int(input("Price : "))
    dict1[key] = value
i=0
print(" KEY ---------> VALUE ") 
for key,value in dict1.items():
    print(" " + key +" -----> " + str(value))

print (dict1)
# Out:
# Enter Size of dict: 5
# Fruit Name : Python
# Price : 85
# Fruit Name : Java
# Price : 78
# Fruit Name : DBMS
# Price : 90
# Fruit Name : Maths
# Price : 88
# Fruit Name : English
# Price : 75
#  KEY ---------> VALUE
#  Python -----> 85
#  Java -----> 78
#  DBMS -----> 90
#  Maths -----> 88
#  English -----> 75
# {'Python': 85, 'Java': 78, 'DBMS': 90, 'Maths': 88, 'English': 75}

# %% [markdown]
# ## Question 19
#
# Take input from the user for `n` students — ID and name — and store them in a dictionary. Then ask the user to search for a student by ID and display their name (or "not found" if the ID doesn't exist).

# %%
dict1= {}
n = int(input("Enter Size of dict: "))
for i in range(n):
    key = input("Student ID  : ")
    value = input("Name : ")
    dict1[key] = value 
keyToSearch = input("Input ID to Search : ")
for j in dict1.keys():
    if(keyToSearch == j):
        print("ID FOUND !!!\n"+dict1[j])
        print()
print (dict1)
# Out:
# Enter Size of dict: 3
# Student ID  : 101
# Name : Krupa Pathak
# Student ID  : 102
# Name : Jeet Pandya
# Student ID  : 103
# Name : Alice Shah
# Input ID to Search : 102
# ID FOUND !!!
# Jeet Pandya
#
# {'101': 'Krupa Pathak', '102': 'Jeet Pandya', '103': 'Alice Shah'}

# %% [markdown]
# ## Question 20
#
# Write a Python program to create a dictionary with 5 student IDs as keys and values as their 5 subject marks. Find the percentage of each student and create a new dictionary to store the percentage along with the student ID.
#
# **Sample Input**
# ```
# e.g. {'23BCA001': [43,45,67,78,89]}
# ```
#
# **Expected Output**
# ```
# output: {'23BCA001': 55}
# ```

# %%
dict1= {}
per=0
n = int(input("Enter Size of dict: "))
for i in range(n):
    key = input("Student ID  : ")
    lis=[]
    for j in range(5):
        k = int(input("Enter data : "))
        lis.append(k)
        per+=k
        print(lis)
    dict1[key] = per/5
print (dict1)
# Out:
# Enter Size of dict: 2
# Student ID  : 23BCA001
# Enter data : 43
# [43]
# Enter data : 45
# [43, 45]
# Enter data : 67
# [43, 45, 67]
# Enter data : 78
# [43, 45, 67, 78]
# Enter data : 89
# [43, 45, 67, 78, 89]
# Student ID  : 23BCA002
# Enter data : 55
# [55]
# Enter data : 60
# [55, 60]
# Enter data : 70
# [55, 60, 70]
# Enter data : 80
# [55, 60, 70, 80]
# Enter data : 90
# [55, 60, 70, 80, 90]
# {'23BCA001': 64.4, '23BCA002': 135.4}

# %% [markdown]
# ## Question 21
#
# Write a Python program to count the **frequency of each character** in a string using a dictionary.
#
# **Sample Input**
# ```
# Enter a string: python programming
# ```
#
# **Expected Output**
# ```
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}
# ```

# %%
str = input("Enter a string: ")
dict={}
for c in str:
    if c in dict:
        dict[c]+=1
    else:
        dict[c] =1
print(dict)
# Out:
# Enter a string: python programming
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}

# %% [markdown]
# ## Question 22
#
# Store the monthly electricity bill of six months in a dictionary. Find the month with the **highest bill**.
#
# **Sample Input**
# ```
# Enter electricity bill for January: 2200
# Enter electricity bill for February: 1850
# Enter electricity bill for March: 2400
# Enter electricity bill for April: 1990
# Enter electricity bill for May: 2100
# Enter electricity bill for June: 1950
# ```
#
# **Expected Output**
# ```
# Highest Electricity Bill
#
# Month : March
# Bill  : ₹2400
# ```

# %%
dict ={
    "January": "",
    "February": "",
    "March" : "",
    "April" : "",
    "May": "",
    "June": "",
    "July" : "",
    "August" : "",
    "September": "",
    "October": "",
    "November" : "",
    "December" : "",
}
greater=0
k=0
for i in dict.keys():
    value = int(input("Enter bill for " + i +" : "))
    dict[i] = value
    if (value>greater):
        greater=value
        k = i

print(k + " : "+ str(greater))
# Out:
# Enter bill for January : 2200
# Enter bill for February : 1850
# Enter bill for March : 2400
# Enter bill for April : 1990
# Enter bill for May : 2100
# Enter bill for June : 1950
# Enter bill for July : 2050
# Enter bill for August : 2300
# Enter bill for September : 2150
# Enter bill for October : 1900
# Enter bill for November : 2000
# Enter bill for December : 2250
# March : 2400

# %% [markdown]
# ## Question 23
#
# Write a Python program to accept two sets of subjects chosen by two students and find:
#
# - Common subjects
# - Subjects only chosen by the first student
# - Union of all chosen subjects
#
# **Sample Input**
# ```
# Enter number of subjects chosen by Student 1: 4
# Enter Subject 1: Python
# Enter Subject 2: Java
# Enter Subject 3: DBMS
# Enter Subject 4: AI
#
# Enter number of subjects chosen by Student 2: 4
# Enter Subject 1: Python
# Enter Subject 2: AI
# Enter Subject 3: C
# Enter Subject 4: Mathematics
# ```
#
# **Expected Output**
# ```
# Student 1 Subjects:
# {'Python', 'Java', 'DBMS', 'AI'}
#
# Student 2 Subjects:
# {'Python', 'AI', 'C', 'Mathematics'}
#
# Common Subjects:
# {'Python', 'AI'}
#
# Subjects only chosen by Student 1:
# {'Java', 'DBMS'}
#
# Union of all Subjects:
# {'Python', 'Java', 'DBMS', 'AI', 'C', 'Mathematics'}
# ```

# %%
set1={"Python","Java","DBMS","AI"}
set2={"Python","C","Mathematics","AI"}
print(set1)
print(set2)
print(set1.intersection(set2))
print(set1.difference(set2))
print((set1) | (set2))
# Out:
# {'Python', 'DBMS', 'AI', 'Java'}
# {'Python', 'Mathematics', 'AI', 'C'}
# {'Python', 'AI'}
# {'DBMS', 'Java'}
# {'Mathematics', 'AI', 'C', 'Python', 'Java', 'DBMS'}

# %% [markdown]
# ## Question 24
#
# Given a set of all roll numbers and another set of students present in class, write a Python program to find and display the roll numbers of **absent students**.
#
# **Sample Input**
# ```
# Enter total number of students: 6
#
# Enter all roll numbers:
# 101
# 102
# 103
# 104
# 105
# 106
#
# Enter number of students present: 4
#
# Enter present roll numbers:
# 101
# 103
# 104
# 106
# ```
#
# **Expected Output**
# ```
# All Roll Numbers:
# {101, 102, 103, 104, 105, 106}
#
# Present Students:
# {101, 103, 104, 106}
#
# Absent Students:
# {102, 105}
# ```

# %%
rollnumbers = {101,102,103,104,105,106}
present=set()
print("Enter present numbers\n")
for i in range(6):
    roll= int(input())
    present.add(roll)
print("Present number : "+str(rollnumbers.intersection(present)))
print("Absent Numbers : " + str(rollnumbers.difference(present)))
# Out:
# Enter present numbers
#
# 101
# 103
# 104
# 106
# 101
# 103
# Present number : {104, 106, 101, 103}
# Absent Numbers : {105, 102}

# %% [markdown]
# ## Question 25
#
# Write a Python function named `greet_user(name)` that accepts a person's name as an argument and prints a welcome message.
#
# **Sample Input**
# ```
# Call: greet_user('Krupa')
# ```
#
# **Expected Output**
# ```
# Output: Welcome to Python Programming, Krupa!
# ```

# %%
def greet_user(name):
    return ("Welcome to Python Programming, "+name)
def main():
    name = input("Enter your name : ")
    print(greet_user(name))
main()
# Out:
# Enter your name : Krupa
# Welcome to Python Programming, Krupa

# %% [markdown]
# ## Question 26
#
# Write a Python function `square_number(num)` that accepts a number and returns its square value.
#
# **Sample Input**
# ```
# Call: square_number(6)
# ```
#
# **Expected Output**
# ```
# Output: Square = 36
# ```

# %%
def sq(n):
    return int(n*n)
def main():
    n = int(input("Enter a nmber : "))
    print("Square is "+ str(sq(n)))
main()
# Out:
# Enter a nmber : 6
# Square is 36

# %% [markdown]
# ## Question 27
#
# Write a Python program using the `sorted()` built-in function to sort a list of student names in both ascending and descending order.
#
# **Sample Input**
# ```
# Input List: ['Krupa', 'Alice', 'David', 'Bob']
# ```
#
# **Expected Output**
# ```
# Ascending: ['Alice', 'Bob', 'David', 'Krupa']
# Descending: ['Krupa', 'David', 'Bob', 'Alice']
# ```

# %%
def name(n:list):
    print(n)
def main():
    n="Hello"
    name(n)
main()
# Out:
# Hello

# %% [markdown]
# ## Question 28
#
# Write a Python function `calculate_simple_interest(principal, rate=7.5, time=1)` using default arguments to calculate interest.
#
# **Sample Input**
# ```
# Call 1: calculate_simple_interest(10000)
# Call 2: calculate_simple_interest(10000, rate=8.0, time=3)
# ```
#
# **Expected Output**
# ```
# Interest 1 = 750.0
# Interest 2 = 2400.0
# ```

# %%
def si(p,r=7.5,t=1):
    return (p*r*t/100)
def main():
    n=int(input("Enter Principal Amount : "))
    print(str(si(n)))
    r=int(input("Enter Rate of interest : "))
    t=int(input("Enter time : "))
    print(str(si(n,r,t)))

# %% [markdown]
# ## Question 29
#
# Write a Python function to calculate the **Body Mass Index (BMI)** using height and weight.
#
# Criteria:
#
# - Input: height (in meters), weight (in kg)
# - Formula: `BMI = weight / height ** 2`
# - Output: BMI value rounded to 2 decimal places

# %%
def bmi(h:float,w:float):
    return (w/(h*h))*1000
def main():
    w=float(input("Enter weight (in kg) : "))
    h=float(input("Enter height (in meters) : "))
    print("Body Mass Index : " + str(bmi(w,h)))
main()
# Out:
# Enter weight (in kg) : 70
# Enter height (in meters) : 1.75
# Body Mass Index : 0.35714285714285715

# %% [markdown]
# ## Question 30
#
# Write a Python function `multiply_all(*args)` using arbitrary positional arguments (`*args`) to multiply any number of given integers.
#
# **Sample Input**
# ```
# Call 1: multiply_all(2, 3, 4)
# Call 2: multiply_all(5, 10)
# ```
#
# **Expected Output**
# ```
# Output 1 = 24
# Output 2 = 50
# ```

# %% [markdown]
# > _No solution file (`30.py`) exists yet for this question._

# %% [markdown]
# ## Question 31
#
# Write a Python menu-driven program using user-defined functions for basic calculator operations (Add, Subtract, Multiply, Divide) that executes continuously until the user chooses to exit.
#
# **Sample Input**
# ```
# Select Choice: 1 (Add) | Inputs: 10, 20
# ```
#
# **Expected Output**
# ```
# Result: 10 + 20 = 30
# ```

# %% [markdown]
# > _No solution file (`31.py`) exists yet for this question._

# %% [markdown]
# ## Question 32
#
# Write a Python function `calculate_grade(marks_list)` that accepts a list of subject marks, calculates the percentage, and returns the Grade (A/B/C/F) along with pass/fail status.
#
# **Sample Input**
# ```
# Call: calculate_grade([80, 75, 90, 85, 70])
# ```
#
# **Expected Output**
# ```
# Percentage: 80.0% | Grade: A | Status: PASSED
# ```

# %% [markdown]
# > _No solution file (`32.py`) exists yet for this question._
